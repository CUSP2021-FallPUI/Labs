# %% [markdown]
# ## 311 complaints analysis
#
# The 311 dataset contains all the non-emergency complaints/service requests covering a wide range of city agencies like Department of Sanitation, Housing, Transportation, NYPD etc. Some common complaints include sidewalk and road repairs, noise, graffiti and others. Depending on the service request, city agencies will answer the question or send municipal services to the location to fix the problem.
#
# The detailed 311 data for NYC from 2010 onwards is available with open access: https://data.cityofnewyork.us/Social-Services/311-Service-Requests-from-2010-to-Present/erm2-nwe9
#
# Owing to the large scale of 311 data, it is quite helpful in analyzing the city-wide trends/anomalies from different perspectives. In this notebook, we'll demonstrate some steps necessary to pre-process the data as well some cases which can help identify the patterns in urban economy. In particular, this notebook contains:
#
# - Important sanity checks for cleaning and pre-processing the data
#
# - Cases with analysis of 311 data with income/real estate data to identify patterns in 311 as a signature of urban economy
# - Working with geopandas for plotting data in maps

# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import datetime 
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# read the 311 data for 2019 (this data contains only sepcific columns we use in this lab)

data = pd.read_csv('311_2019.csv')

# convert complaint date to datetime format
data['Created Date'] = pd.to_datetime(data['Created Date'])
data.head()
# Out:
# /Users/devashishkhulbe/opt/anaconda3/envs/py39/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    Unique Key        Created Date Agency  Complaint Type    Location Type  \
# 0    43162639 2019-06-29 13:05:22    TLC  Taxi Complaint              NaN
# 1    44079566 2019-10-17 08:25:14    DPR    Damaged Tree  Street/Curbside
# 2    45211021 2019-12-20 06:54:38   DSNY        Graffiti        Mixed Use
# 3    45232110 2019-12-23 08:48:30   DSNY        Graffiti        Mixed Use
# 4    43573777 2019-08-17 02:30:39   DSNY        Graffiti      Residential
#
#   Incident Zip   Latitude  Longitude                                 Location
# 0          NaN        NaN        NaN                                      NaN
# 1      11434.0  40.670854 -73.771876   (40.6708540271649, -73.77187597753328)
# 2      11212.0  40.663072 -73.925752  (40.66307167932628, -73.92575181328998)
# 3      10016.0  40.744629 -73.976001  (40.74462912186954, -73.97600102823421)
# 4      10032.0  40.835618 -73.945652   (40.83561762599567, -73.9456520072136)

# %% [markdown]
# Column descriptions:
#
# - Unique Key: unique number for a 311 call/request data point
#
# - Created Date: date and time of the call
#
# - Agency: name of city agency the call is attributed to
#
# - Complaint type: description of the compaint
#
# - Latitude/Longitude/Location: coordinates of the 311 complaints
#
# There are other columns in the complete 311 data like Status, Intersection Name, etc. which are not included here in this notebook. Please check the complete 311 documentation from NYC open data for details.

# %%
data.shape
# Out:
# (802745, 9)

# %% [markdown]
# ### Data cleaning and sanity checks

# %% [markdown]
# #### The data may have a lot of errors/missing records. We'll try to diagnose these issues and remove the concerned rows

# %%
# first - let's check the unique zip codes in the data

data['Incident Zip'].unique()
# Out:
# array([nan, 11434.0, 11212.0, 10016.0, 10032.0, 11420.0, 11105.0, 10470.0,
#        10461.0, 10454.0, 11226.0, 11357.0, 10019.0, 10035.0, 11218.0,
#        11694.0, 10022.0, 11419.0, 11385.0, 11216.0, 11207.0, 10034.0,
#        11375.0, 11374.0, 11411.0, 11106.0, 11220.0, 10305.0, 11430.0,
#        10017.0, 11372.0, 11201.0, 10453.0, 11358.0, 11421.0, 11223.0,
#        11691.0, 11368.0, 10306.0, 11436.0, 10304.0, 10027.0, 10452.0,
#        10466.0, 11203.0, 11210.0, 11214.0, 10459.0, 11423.0, 11432.0,
#        11236.0, 10463.0, 11208.0, 10028.0, 10469.0, 11249.0, 11238.0,
#        10033.0, 11229.0, 10465.0, 11370.0, 10024.0, 11234.0, 11356.0,
#        11377.0, 11206.0, 11418.0, 11414.0, 10307.0, 10460.0, 11412.0,
#        11233.0, 11415.0, 10039.0, 11232.0, 11213.0, 11222.0, 11378.0,
#        11427.0, 11422.0, 11228.0, 11413.0, 10002.0, 11104.0, 11215.0,
#        11364.0, 10023.0, 10025.0, 11235.0, 11367.0, 11379.0, 11231.0,
#        11365.0, 10003.0, 11209.0, 10014.0, 11435.0, 11354.0, 10031.0,
#        10467.0, 10458.0, 11429.0, 10021.0, 10030.0, 11355.0, 10312.0,
#        10012.0, 11363.0, 10464.0, 11102.0, 10303.0, 11373.0, 11103.0,
#        11360.0, 11230.0, 11221.0, 11362.0, 11417.0, 7310.0, 11219.0,
#        10314.0, 11366.0, 10029.0, 10013.0, 7631.0, 11361.0, 10472.0,
#        11217.0, 7974.0, 10310.0, 10038.0, 11428.0, 11204.0, 11211.0,
#        10282.0, 10010.0, 10302.0, 10026.0, 10309.0, 11101.0, 10301.0,
#        10040.0, 10457.0, 10308.0, 11369.0, 10471.0, 10473.0, 10036.0,
#        10011.0, 11225.0, 10475.0, 10075.0, 11005.0, 10451.0, 10456.0,
#        11433.0, 7114.0, 11224.0, 10474.0, 10128.0, 7605.0, 10001.0,
#        10065.0, 10468.0, 10007.0, 11426.0, 11205.0, 10455.0, 10009.0,
#        10006.0, 10462.0, 11001.0, 11237.0, 10069.0, 10005.0, 10004.0,
#        11004.0, 11030.0, 10121.0, 11416.0, 11693.0, 10020.0, 10018.0,
#        10000.0, 10037.0, 11359.0, 11692.0, 11239.0, 10162.0, 11697.0,
#        10120.0, 11040.0, 10281.0, 10111.0, 10169.0, 10122.0, 10176.0,
#        10280.0, 10044.0, 11109.0, 10119.0, 10151.0, 10279.0, 10041.0,
#        10110.0, 10278.0, 10158.0, 11695.0, 10152.0, 10055.0, 11242.0,
#        10168.0, 10048.0, 11251.0, 10118.0, 10080.0, 10177.0, 11241.0,
#        10174.0, 10153.0, 10103.0, 12345.0, 10165.0, 10179.0, 10155.0,
#        10105.0, 10123.0, 10171.0, 10172.0, 10106.0, 10115.0, 10112.0,
#        11371.0, 10154.0, 10167.0, 11741.0, 10173.0, 10107.0, 10045.0,
#        10178.0, 10271.0, 10170.0, '10004.0', '11220.0', '10009.0',
#        '10032.0', '10314.0', '10452.0', '11360.0', '10466.0', '11412.0',
#        '10461.0', '11378.0', '10454.0', '11205.0', '10469.0', '10029.0',
#        '11231.0', '10457.0', '11214.0', '10472.0', '10030.0', '10455.0',
#        '10001.0', '10463.0', '10010.0', '11206.0', '11203.0', '10458.0',
#        '11433.0', '11434.0', '11375.0', '11238.0', '11228.0', '11101.0',
#        '11226.0', '11105.0', '10465.0', '11419.0', '11233.0', '11370.0',
#        '11208.0', '11372.0', '11217.0', '10002.0', '11204.0', '11366.0',
#        '11201.0', '10035.0', '11369.0', '10021.0', '11224.0', '10462.0',
#        '10456.0', '10003.0', '10028.0', '11223.0', '11213.0', '10065.0',
#        '10022.0', '10474.0', '10024.0', '10038.0', '11229.0', '10304.0',
#        '10039.0', '11418.0', '10309.0', '10011.0', '11420.0', '11356.0',
#        '10303.0', '10121.0', '10016.0', '11365.0', '10036.0', '10019.0',
#        '10025.0', '10075.0', '11209.0', '11236.0', '10451.0', '11415.0',
#        '11354.0', '11362.0', '11358.0', '11364.0', '10027.0', '11222.0',
#        '11210.0', '10017.0', '11435.0', '11207.0', '11237.0', '11355.0',
#        '11235.0', '10013.0', '10128.0', '11373.0', '11363.0', '10018.0',
#        '11432.0', '10026.0', '10308.0', '10301.0', '11234.0', '11221.0',
#        '10033.0', '11104.0', '10473.0', '11219.0', '10459.0', '10467.0',
#        '11368.0', '11218.0', '10460.0', '10037.0', '11357.0', '10012.0',
#        '11413.0', '10310.0', '11426.0', '11230.0', '11106.0', '11216.0',
#        '11225.0', '11361.0', '11416.0', '11211.0', '10014.0', '11215.0',
#        '10470.0', '11421.0', '10023.0', '11385.0', '11422.0', '11428.0',
#        '11367.0', '11212.0', '11423.0', '10302.0', '11691.0', '11417.0',
#        '10031.0', '10040.0', '11379.0', '11429.0', '11102.0', '10005.0',
#        '10453.0', '11414.0', '11232.0', '10007.0', '11377.0', '10305.0',
#        '10307.0', '10468.0', '11103.0', '11249.0', '11692.0', '10306.0',
#        '11374.0', '10282.0', '10034.0', '10006.0', '11694.0', '10312.0',
#        '11693.0', '11430.0', '10041.0', '11411.0', '10471.0', '11004.0',
#        '11427.0', '11239.0', '10020.0', '10464.0', '10475.0', '10119.0',
#        '11040.0', '11436.0', '11109.0', '11005.0', '10280.0', '10162.0',
#        '11001.0', '10169.0', '10069.0', '10279.0', '10000.0', '10168.0',
#        '10118.0', '10105.0', '10044.0', '10171.0', '11371.0', '10120.0',
#        '10451', '10016', '10453', '10012', '11358', '10075', '10010',
#        '10461', '10128', '10034', '11237', '10314', '10472', '11354',
#        '11234', '10471', '11223', '10306', '10002', '11418', '11213',
#        '11429', '10009', '11201', '10032', '11218', '11415', '11385',
#        '10001', '11103', '11379', '11221', '10003', '11229', '11375',
#        '10312', '10036', '11203', '10021', '10454', '10302', '11214',
#        '11225', '11233', '10025', '11215', '10031', '10458', '10019',
#        '11220', '10017', '11102', '11372', '10023', '11373', '10005',
#        '10468', '11211', '10011', '10153', '11691', '11249', '10027',
#        '10028', '10474', '10018', '11435', '10026', '11212', '11206',
#        '11210', '11217', '11101', '11364', '11693', '11004', '11209',
#        '11222', '11432', '11235', '11226', '10467', '11421', '10465',
#        '11369', '11374', '10452', '10038', '10462', '11224', '10469',
#        '11370', '11378', '11236', '10459', '11205', '10037', '11207',
#        '10039', '11365', '10463', '10035', '10013', '11430', '11368',
#        '11228', '11230', '10310', '10456', '11357', '10014', '11377',
#        '10024', '11413', '11106', '10308', '11219', '10475', '10473',
#        '11105', '11232', '11422', '11216', '11420', '11694', '10301',
#        '11355', '11366', '11231', '10007', '10281', '11426', '10022',
#        '11356', '10309', '10464', '11367', '11434', '11104', '11238',
#        '11204', '10033', '11361', '11419', '10304', '10455', '11239',
#        '11412', '11109', '11433', '10029', '10305', '11417', '10460',
#        '11423', '10004', '10020', '10457', '10065', '10006', '11360',
#        '10470', '11411', '11692', '11427', '08542', '11208', '10030',
#        '11414', '11040', '11023', '10303', '11436', '10307', '10466',
#        '11428', '11362', '10040', '11416', '07029', '11001', '11005',
#        '11363', '11371', '07031', '10173.0', '10176.0', '0.0', '10106.0',
#        '10041', '10603', '10000', '10069', '12222', '10096', 'DID N',
#        '10278', '10121', '10112.0', '10151.0', '10111.0', '10174.0',
#        '10281.0', '10103.0', '10123.0', '10122.0', '10271.0', '11697.0',
#        '11695.0', '11359.0', '10165.0', '11695', '10280', '11697',
#        '10044', 11570.0, 7073.0, 10801.0, 3784.0, 14614.0, 0.0, 75320.0,
#        7302.0, 43537.0, 11042.0, 21773.0, 7307.0, 10706.0, 11011.0,
#        10704.0, 33130.0, 7055.0, 11742.0, 7032.0, 12222.0, 44060.0,
#        11550.0, 10591.0, 78681.0, 33624.0, 11514.0, 7632.0, '10153.0',
#        '7302.0', '11791.0', '7114.0', '11572.0', '11717.0', '10177.0',
#        '12345.0', '11251.0', '11741', '11559', '07114', '10282', '11795',
#        '07310', 'UNK', '11359', '06093', '11747', '11572', '000000',
#        '11779', '10177', 'NJ 07114', '00000', '07304', 'W1', '11021',
#        '07607', '8701.0', '12222.0', '7030.0', '8081.0', '10803.0',
#        '33434.0', '7047.0', '08401', '10707', '11580', '11021.0',
#        '11758.0', '7024.0', '10278.0', '11242.0', '14068.0', '11577.0',
#        '7079.0', '10543.0', '11520.0', '11559.0', '7626.0', '11563.0',
#        '7080.0', '10606.0', '11561.0', '10704.0', '10279', 'NJ070',
#        '11030', '10962', '07631', '83.0', '10705.0', '7631.0', '11011.0',
#        '19342.0', '7666.0', '11516.0', '11590.0', '7303.0', '11030.0',
#        '11042.0', '11518.0', '7026.0', '11550.0', '7078.0', '2132.0',
#        '7306.0', '7203.0', '7055.0', '11580.0', '94129.0', '10956.0',
#        '10579.0', '7003.0', '10158.0', '881.0', '10154.0', '10530.0',
#        '11576.0', '10110.0', '7430.0', '11803.0', '11735.0', '32501.0',
#        '10605.0', '11575.0', '7087.0', '10170.0', '13748.0', '10538.0',
#        '11801.0', '10172.0', '6851.0', '11553.0', '11012.0', '7310.0',
#        '7305.0', '2298.0', '32896.0', '11530.0', '94402.0', '06851', '1',
#        '07087', '10983', '11251', '10119', '46219', 'NJ 07', '10103',
#        '10120', '11598', '11530', '84119', '11581', '10708', '10522',
#        '07030', '10169', '07302', '11749', '11706', '31131', '33756',
#        '10710', '80202', '10537', '07032', '55102-1211', '11967', '10552',
#        '07001', '10149', '11735', '11553', '11803', '10272', '11024.0',
#        '07202', '11516', '10110', '11797', '11701', '11710', '10151',
#        '10550.0', '31093.0', '11023.0', '11335.0', '11581.0', '11725.0',
#        '11704.0', '08837', '11003', '0', '06901', '07071', '07083',
#        '06880', '06067', '06870', '07050', '10174', '11756', '11758',
#        '12754', '33069', '10977', '07094', '10802', '89119', '11024',
#        '10801', '11722', '07093', 'LE4', '11042', '08536', '10702',
#        '11963', '07654', '08830', '08865', '10562', '07641', '07632',
#        '10803', '10107', 'UNKNOWN', '11577', '11561', '11740', '10179.0'],
#       dtype=object)

# %% [markdown]
# The data has many nan values as well as codes which are obvious errors (example - "7030", "W1" etc.)

# %%
# filter out nans

data.dropna(subset=['Incident Zip'], inplace=True)

# %%
# convert the zip codes to numeric type - this will remove all word (string) zips

data['Incident Zip'] = pd.to_numeric(data['Incident Zip'], errors='coerce')

# %%
# !git clone https://github.com/CUSP2021-FallPUI/Labs.git

# %%
# next - read the NYC zip code shapefile filter the 311 data to keep only NYC zips

zips = gpd.read_file('ZIPCODE/ZIP_CODE_040114.shp')
zips['ZIPCODE'] = zips['ZIPCODE'].astype(int)
zips.head()
# Out:
#    ZIPCODE BLDGZIP   PO_NAME  POPULATION          AREA STATE  COUNTY ST_FIPS  \
# 0    11436       0   Jamaica     18681.0  2.269930e+07    NY  Queens      36
# 1    11213       0  Brooklyn     62426.0  2.963100e+07    NY   Kings      36
# 2    11212       0  Brooklyn     83866.0  4.197210e+07    NY   Kings      36
# 3    11225       0  Brooklyn     56527.0  2.369863e+07    NY   Kings      36
# 4    11218       0  Brooklyn     72280.0  3.686880e+07    NY   Kings      36
#
#   CTY_FIPS                   URL  SHAPE_AREA  SHAPE_LEN  \
# 0      081  http://www.usps.com/         0.0        0.0
# 1      047  http://www.usps.com/         0.0        0.0
# 2      047  http://www.usps.com/         0.0        0.0
# 3      047  http://www.usps.com/         0.0        0.0
# 4      047  http://www.usps.com/         0.0        0.0
#
#                                             geometry
# 0  POLYGON ((1038098.252 188138.380, 1038141.936 ...
# 1  POLYGON ((1001613.713 186926.440, 1002314.243 ...
# 2  POLYGON ((1011174.276 183696.338, 1011373.584 ...
# 3  POLYGON ((995908.365 183617.613, 996522.848 18...
# 4  POLYGON ((991997.113 176307.496, 992042.798 17...

# %%
data = data[data['Incident Zip'].isin(zips.ZIPCODE)]
data.shape
# Out:
# (766126, 10)

# %% [markdown]
# ~ 4% records are filtered out

# %%
# get hour of complaint (from the datetime)

data['complaint_hour'] = data['Created Date'].dt.hour
data.head()
# Out:
#    Unique Key        Created Date Agency      Complaint Type  \
# 1    44079566 2019-10-17 08:25:14    DPR        Damaged Tree
# 2    45211021 2019-12-20 06:54:38   DSNY            Graffiti
# 3    45232110 2019-12-23 08:48:30   DSNY            Graffiti
# 4    43573777 2019-08-17 02:30:39   DSNY            Graffiti
# 5    43524214 2019-08-11 23:46:01   NYPD  Noise - Commercial
#
#       Location Type  Incident Zip   Latitude  Longitude  \
# 1   Street/Curbside       11434.0  40.670854 -73.771876
# 2         Mixed Use       11212.0  40.663072 -73.925752
# 3         Mixed Use       10016.0  40.744629 -73.976001
# 4       Residential       10032.0  40.835618 -73.945652
# 5  Store/Commercial       11420.0  40.675929 -73.818015
#
#                                   Location  complaint_hour
# 1   (40.6708540271649, -73.77187597753328)               8
# 2  (40.66307167932628, -73.92575181328998)               6
# 3  (40.74462912186954, -73.97600102823421)               8
# 4   (40.83561762599567, -73.9456520072136)               2
# 5  (40.67592902161404, -73.81801548500097)              23

# %%
# check the complaint volume by hour

sns.countplot(data.complaint_hour)
# Out:
# /Users/devashishkhulbe/opt/anaconda3/envs/py39/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='complaint_hour', ylabel='count'>

# %% [markdown]
# unusually high number of complaints at noon, probably due to some error in assigning times to the calls. Let's check the complaints at noon

# %%
data['complaint_time'] = data['Created Date'].dt.time
len(data[data.complaint_time == datetime.time(12, 0, 0)])
# Out:
# 21013

# %% [markdown]
# ~ 21k complaints are assigned at exact noon, which is quite high considering the number of complaints surrounding noon times (11am, 1pm), which are around ~40k. So, it is very likely that the exact noon (12:00:00) complaints are not legit.

# %%
# remove the excess noon complaints from the data

data = data[~(data['complaint_time'] == datetime.time(12, 0, 0))]
data.shape
# Out:
# (745113, 11)

# %%
# next, check the number of total complaints in 2019 by zipcode

byZip = data.groupby(by='Incident Zip', as_index=False).count()[['Incident Zip', 'Unique Key']].rename(columns={'Unique Key':'N_complaints'})
byZip
# Out:
#      Incident Zip  N_complaints
# 0            83.0             4
# 1         10001.0          4819
# 2         10002.0          7769
# 3         10003.0          7398
# 4         10004.0          1401
# ..            ...           ...
# 225       11691.0          3214
# 226       11692.0           911
# 227       11693.0           989
# 228       11694.0          1985
# 229       11697.0           361
#
# [230 rows x 2 columns]

# %%
# plot as a heatmap

byZip_plot = zips.merge(byZip, left_on='ZIPCODE', right_on='Incident Zip')
byZip_plot.plot(column='N_complaints', figsize=(7,7), legend=True)
plt.title('311 complaints by zip code')
# Out:
# Text(0.5, 1.0, '311 complaints by zip code')

# %% [markdown]
# let's further calculate the normalized number of complaints by zipcode. We'll use area for normalization here.

# %%
# normalize number of complaints by area and plot

# convert sq.ft. to sq.miles
byZip_plot['area_sqMile'] = byZip_plot['AREA']/27880000
# divide by area
byZip_plot['complaints_norm'] = byZip_plot['N_complaints']/byZip_plot['area_sqMile']
byZip_plot.plot(column='complaints_norm', figsize=(9,9), scheme='quantiles', legend=True)
plt.title('normalized 311 complaints (by area) by zip code')
# Out:
# Text(0.5, 1.0, 'normalized 311 complaints (by area) by zip code')

# %%
byZip.sort_values(by='N_complaints')
# Out:
#      Incident Zip  N_complaints
# 48        10096.0             1
# 47        10080.0             1
# 76        10171.0             2
# 43        10055.0             3
# 68        10155.0             3
# ..            ...           ...
# 171       11237.0          8768
# 137       11201.0          8888
# 156       11221.0          9672
# 161       11226.0          9937
# 201       11385.0         13387
#
# [230 rows x 2 columns]

# %% [markdown]
# many zip codes have just a small number of 311 requests for the year. Let's keep only the zipcodes there are at least 100 complaints.

# %%
# number of zips with >100 311 complaints

byZip[byZip.N_complaints > 100].shape
# Out:
# (184, 2)

# %%
# keep only the zips with >100 complaints

data = data[data['Incident Zip'].isin(byZip[byZip.N_complaints > 100]['Incident Zip'])]

# %%
data.shape
# Out:
# (744284, 11)

# %% [markdown]
# ~ 0.1% records further removed

# %% [markdown]
# ## Business-time complaints vs per-capita income
#
# The areas with high commercial activity may have high real estate pricing and consequently high income people living there.
#
# Let's check if there is any relation between the number of complaints during business hours (9am-6pm) and per capita income in a neighborhood.

# %%
# get day of week from the date (0-5 are weekdays, 5 and 6 are weekends)

data['weekday'] = data['Created Date'].dt.weekday
data.head()
# Out:
#    Unique Key        Created Date Agency      Complaint Type  \
# 1    44079566 2019-10-17 08:25:14    DPR        Damaged Tree
# 2    45211021 2019-12-20 06:54:38   DSNY            Graffiti
# 3    45232110 2019-12-23 08:48:30   DSNY            Graffiti
# 4    43573777 2019-08-17 02:30:39   DSNY            Graffiti
# 5    43524214 2019-08-11 23:46:01   NYPD  Noise - Commercial
#
#       Location Type  Incident Zip   Latitude  Longitude  \
# 1   Street/Curbside       11434.0  40.670854 -73.771876
# 2         Mixed Use       11212.0  40.663072 -73.925752
# 3         Mixed Use       10016.0  40.744629 -73.976001
# 4       Residential       10032.0  40.835618 -73.945652
# 5  Store/Commercial       11420.0  40.675929 -73.818015
#
#                                   Location  complaint_hour complaint_time  \
# 1   (40.6708540271649, -73.77187597753328)               8       08:25:14
# 2  (40.66307167932628, -73.92575181328998)               6       06:54:38
# 3  (40.74462912186954, -73.97600102823421)               8       08:48:30
# 4   (40.83561762599567, -73.9456520072136)               2       02:30:39
# 5  (40.67592902161404, -73.81801548500097)              23       23:46:01
#
#    weekday
# 1        3
# 2        4
# 3        0
# 4        5
# 5        6

# %%
# make another column describing business time complaints as "business_time"

# mon-fri
business_days = [0, 1, 2, 3, 4]

data['complaint_description'] = 'other'

# attribute 9am-6pm complaints on weekdays as business time complaints
data.loc[(data.complaint_hour > 8) & (data.complaint_hour < 19) & (data.weekday.isin(business_days)), 
         'complaint_description'] = 'business_time'
data.head()
# Out:
#    Unique Key        Created Date Agency      Complaint Type  \
# 1    44079566 2019-10-17 08:25:14    DPR        Damaged Tree
# 2    45211021 2019-12-20 06:54:38   DSNY            Graffiti
# 3    45232110 2019-12-23 08:48:30   DSNY            Graffiti
# 4    43573777 2019-08-17 02:30:39   DSNY            Graffiti
# 5    43524214 2019-08-11 23:46:01   NYPD  Noise - Commercial
#
#       Location Type  Incident Zip   Latitude  Longitude  \
# 1   Street/Curbside       11434.0  40.670854 -73.771876
# 2         Mixed Use       11212.0  40.663072 -73.925752
# 3         Mixed Use       10016.0  40.744629 -73.976001
# 4       Residential       10032.0  40.835618 -73.945652
# 5  Store/Commercial       11420.0  40.675929 -73.818015
#
#                                   Location  complaint_hour complaint_time  \
# 1   (40.6708540271649, -73.77187597753328)               8       08:25:14
# 2  (40.66307167932628, -73.92575181328998)               6       06:54:38
# 3  (40.74462912186954, -73.97600102823421)               8       08:48:30
# 4   (40.83561762599567, -73.9456520072136)               2       02:30:39
# 5  (40.67592902161404, -73.81801548500097)              23       23:46:01
#
#    weekday complaint_description
# 1        3                 other
# 2        4                 other
# 3        0                 other
# 4        5                 other
# 5        6                 other

# %%
# number of complaints business time vs others

sns.countplot(data.complaint_description)
# Out:
# /Users/devashishkhulbe/opt/anaconda3/envs/py39/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='complaint_description', ylabel='count'>

# %%
# now calculate the business time complaints as a % of total 311 complaints for each zip code

complaint_perc = data.groupby(by=['Incident Zip', 'complaint_description']).count()[['Unique Key']]
complaint_perc = complaint_perc.groupby(level=0).apply(lambda x:100 * x / float(x.sum()))
complaint_perc.reset_index(inplace=True)
complaint_perc.rename(columns={'Unique Key':'perc_complaints'}, inplace=True)
complaint_perc.head()
# Out:
#    Incident Zip complaint_description  perc_complaints
# 0       10001.0         business_time        43.369994
# 1       10001.0                 other        56.630006
# 2       10002.0         business_time        38.010040
# 3       10002.0                 other        61.989960
# 4       10003.0         business_time        39.497161

# %%
# 2019 income data (in USD) per zip code - retrieved from official US census www.census.gov

income = pd.read_csv('https://raw.githubusercontent.com/CUSP2021-FallPUI/Labs/main/IncomeEduReg.csv')
income = income[['Zipcode', 'IncomePerCapita']]
income.head()
# Out:
#    Zipcode  IncomePerCapita
# 0    10001          77512.0
# 1    10002          26905.0
# 2    10003          79088.0
# 3    10004          98020.0
# 4    10005          99633.0

# %%
# merge the median sale price data with 311 business time % complaints

complaint_perc_bus = complaint_perc.loc[complaint_perc.complaint_description == 'business_time', :]
comp_sales = complaint_perc_bus.merge(income, left_on='Incident Zip', right_on='Zipcode')
comp_sales.head()
# Out:
#    Incident Zip complaint_description  perc_complaints  Zipcode  \
# 0       10001.0         business_time        43.369994    10001
# 1       10002.0         business_time        38.010040    10002
# 2       10003.0         business_time        39.497161    10003
# 3       10004.0         business_time        52.676660    10004
# 4       10005.0         business_time        55.334988    10005
#
#    IncomePerCapita
# 0          77512.0
# 1          26905.0
# 2          79088.0
# 3          98020.0
# 4          99633.0

# %%
# correlation

comp_sales[['perc_complaints', 'IncomePerCapita']].corr()
# Out:
#                  perc_complaints  IncomePerCapita
# perc_complaints         1.000000         0.442813
# IncomePerCapita         0.442813         1.000000

# %% [markdown]
# ~ 0.44

# %%
# plot in a heatmap

comp_sales_plot = zips.merge(comp_sales, left_on='ZIPCODE', right_on='Incident Zip')
comp_sales_plot.plot(column='perc_complaints', figsize=(9,7), legend=True)
plt.title('% business time complaints')
# Out:
# Text(0.5, 1.0, '% business time complaints')

# %%
# income

comp_sales_plot.plot(column='IncomePerCapita', scheme='quantiles', figsize=(9,7), legend=True)
plt.title('income per capita')
# Out:
# Text(0.5, 1.0, 'income per capita')

# %% [markdown]
# We do see some neighborhoods in Brooklyn, Bronx and Upper Manhattan where income correlates with the commercial 311 complaints.

# %% [markdown]
# ## All business complaints vs. real estate
#
# Next, we'll see if there's any relation between all 311 complaints attributed to business/commercial spaces and the real estate market in an area.

# %%
# check unique location type present in data

data['Location Type'].unique()
# Out:
# array(['Street/Curbside', 'Mixed Use', 'Residential', 'Store/Commercial',
#        nan, 'Comercial', 'Street', '1-2 Family Dwelling',
#        'Street/Sidewalk', 'Bike Lane', 'Residential Building/House',
#        'Sidewalk', 'Above Address', 'Taxi', 'Other (Explain Below)',
#        'Commercial Building', 'Park', 'Club/Bar/Restaurant',
#        'Park/Playground', 'Property Address', '1-, 2- and 3- Family Home',
#        'Co-Op Unit', 'Senior Address', 'Condo Unit', 'Address',
#        'Government/Not-for Profit', 'Commercial', 'RESIDENTIAL BUILDING',
#        'Apartment Building', 'Beach', 'Pool',
#        '3+ Family Apartment Building', 'Residential Building',
#        'Street Area', 'Construction Site', 'Restaurant/Bar/Deli/Bakery',
#        'Mobile Food Vendor', 'Curb', 'Catch Basin/Sewer',
#        'Food Cart Vendor', '3+ Family Apt. Building',
#        '3+ Family Mixed Use Building', 'House of Worship',
#        '1-2 Family Mixed Use Building', 'Bus Stop Shelter', 'Other',
#        'Vacant Lot', 'Tattoo Parlor', 'Parking Lot/Garage', 'Highway',
#        'Subway', 'Roadway Tunnel', 'Government Building',
#        'Public/Unfenced Area', 'Groomer', 'Restaurant',
#        'Residential Property', 'Lot', 'Vacant Lot/Property', 'School',
#        'Apartment', 'Commercial Property', 'Catering Service',
#        'Parking Lot', 'Vacant Building', 'Bridge', 'Crosswalk',
#        'Private House', 'Building-Wide', 'Street Vendor',
#        'School Safety Zone', 'House and Store', 'Abandoned Building',
#        'School/Pre-School', 'Residence', 'Vehicle Lane',
#        'Single Room Occupancy (SRO)', 'Street Fair Vendor',
#        'Green Cart Vendor', 'Building',
#        'Other (explain in Complaint Details)', 'Public Park/Garden',
#        'Kennel/Animal Shelter', 'Overpass', 'Cafeteria - Public School',
#        'Cemetery', "Veterinarian's Office", '1-3 Family Dwelling',
#        'Cafeteria - College/University', 'Office Building',
#        'Medical Facility', 'Ferry', 'Public Garden',
#        '1-3 Family Mixed Use Building', 'Common Area', 'Hallway',
#        'Stairwell', 'Private School', 'Public Garden/Park', 'Garage',
#        'Nail Salon', 'Building (Non-Residential)', 'Speed Reducer',
#        'Ground', 'Hospital', 'Homeless Shelter', 'Lobby', 'Grocery Store',
#        'Store', 'Public Stairs', "Doctor's Office", 'Senior Center',
#        'Day Care/Nursery', 'Sauna', 'Soup Kitchen', 'Cafeteria',
#        'Swamp or Pond', 'Subway Station', 'Petting Zoo/Animal Exhibit',
#        'Retail Store', 'Cafeteria - Private', 'Roadway',
#        'Bridge/Underpass', 'Terminal', 'Nursing Home', 'Horse Stable',
#        'Recreation Center', 'Public Area', 'Theater', 'Health Club',
#        'Catering Hall', 'School - K-12 Public', 'Permanent Food Stand',
#        'Airport or Train/Bus Station', 'Cafeteria - Private School',
#        'School - College/University', 'Steam Room', 'Private Residence',
#        'Public School', 'School - K-12 Private', 'Roof',
#        "Dentist's Office", 'Spa Pool', 'Golf', 'Vacant Land',
#        'Wooded Area', 'Street and Sidewalk', 'Sports Arena'], dtype=object)

# %% [markdown]
# For business/commercial spaces, we'll consider commercial buildings, restaurants, stores, clubs etc.

# %%
# all business locations

business_loc = ['Commercial Building', 'Restaurant/Bar/Deli/Bakery', 'Building (Non-Residential)', 
               'Club/Bar/Restaurant', 'Restaurant', 'Commercial', 'Store', 'Food Establishment', 'Store/Commercial']

# %%
# make another column for location description - "business" and "other"

data['loc_description'] = 'other'
data.loc[data['Location Type'].isin(business_loc), 'loc_description'] = 'business'
data.head()
# Out:
#    Unique Key        Created Date Agency      Complaint Type  \
# 1    44079566 2019-10-17 08:25:14    DPR        Damaged Tree
# 2    45211021 2019-12-20 06:54:38   DSNY            Graffiti
# 3    45232110 2019-12-23 08:48:30   DSNY            Graffiti
# 4    43573777 2019-08-17 02:30:39   DSNY            Graffiti
# 5    43524214 2019-08-11 23:46:01   NYPD  Noise - Commercial
#
#       Location Type  Incident Zip   Latitude  Longitude  \
# 1   Street/Curbside       11434.0  40.670854 -73.771876
# 2         Mixed Use       11212.0  40.663072 -73.925752
# 3         Mixed Use       10016.0  40.744629 -73.976001
# 4       Residential       10032.0  40.835618 -73.945652
# 5  Store/Commercial       11420.0  40.675929 -73.818015
#
#                                   Location  complaint_hour complaint_time  \
# 1   (40.6708540271649, -73.77187597753328)               8       08:25:14
# 2  (40.66307167932628, -73.92575181328998)               6       06:54:38
# 3  (40.74462912186954, -73.97600102823421)               8       08:48:30
# 4   (40.83561762599567, -73.9456520072136)               2       02:30:39
# 5  (40.67592902161404, -73.81801548500097)              23       23:46:01
#
#    weekday complaint_description loc_description
# 1        3                 other           other
# 2        4                 other           other
# 3        0                 other           other
# 4        5                 other           other
# 5        6                 other        business

# %%
# % of business complaints by zipcode

complaint_perc = data.groupby(by=['Incident Zip', 'loc_description']).count()[['Unique Key']]
complaint_perc = complaint_perc.groupby(level=0).apply(lambda x:100 * x / float(x.sum()))
complaint_perc.reset_index(inplace=True)
complaint_perc.rename(columns={'Unique Key':'perc_complaints'}, inplace=True)
complaint_perc.head()
# Out:
#    Incident Zip loc_description  perc_complaints
# 0       10001.0        business         8.798506
# 1       10001.0           other        91.201494
# 2       10002.0        business         8.636890
# 3       10002.0           other        91.363110
# 4       10003.0        business         8.313058

# %%
# !unzip Labs/real_estate.csv.zip real_estate.csv

# %%
# NYC house sales data

sales = pd.read_csv('real_estate.csv')
sales.head()
# Out:
#    BOROUGH  BLOCK  LOT                      BUILDING CLASS CATEGORY  \
# 0        4    976   10  01 ONE FAMILY DWELLINGS
# 1        4    976   10  01 ONE FAMILY DWELLINGS
# 2        4    976   11  01 ONE FAMILY DWELLINGS
# 3        4    976   11  01 ONE FAMILY DWELLINGS
# 4        4    976   15  01 ONE FAMILY DWELLINGS
#
#                ADDRESS  ZIP CODE  GROSS SQUARE FEET  YEAR BUILT  SALE PRICE  \
# 0    21-10 81ST STREET   11370.0             1224.0      1950.0      600000
# 1  21-10 81ST   STREET   11370.0             1224.0      1950.0      750000
# 2    21-12 81ST STREET   11370.0             1224.0      1950.0      600000
# 3  21-12 81ST   STREET   11370.0             1224.0      1950.0      730000
# 4    21-20 81ST STREET   11370.0             1224.0      1950.0      792000
#
#     SALE DATE
# 0  2017-04-10
# 1  2017-06-16
# 2  2017-04-10
# 3  2017-08-23
# 4  2017-07-26

# %%
# calculate price per sq.ft.

sales['price_perSqf'] = sales['SALE PRICE']/sales['GROSS SQUARE FEET']
sales.head()
# Out:
#    BOROUGH  BLOCK  LOT                      BUILDING CLASS CATEGORY  \
# 0        4    976   10  01 ONE FAMILY DWELLINGS
# 1        4    976   10  01 ONE FAMILY DWELLINGS
# 2        4    976   11  01 ONE FAMILY DWELLINGS
# 3        4    976   11  01 ONE FAMILY DWELLINGS
# 4        4    976   15  01 ONE FAMILY DWELLINGS
#
#                ADDRESS  ZIP CODE  GROSS SQUARE FEET  YEAR BUILT  SALE PRICE  \
# 0    21-10 81ST STREET   11370.0             1224.0      1950.0      600000
# 1  21-10 81ST   STREET   11370.0             1224.0      1950.0      750000
# 2    21-12 81ST STREET   11370.0             1224.0      1950.0      600000
# 3  21-12 81ST   STREET   11370.0             1224.0      1950.0      730000
# 4    21-20 81ST STREET   11370.0             1224.0      1950.0      792000
#
#     SALE DATE  price_perSqf
# 0  2017-04-10    490.196078
# 1  2017-06-16    612.745098
# 2  2017-04-10    490.196078
# 3  2017-08-23    596.405229
# 4  2017-07-26    647.058824

# %%
# calculate the median price by zipcode

sales_median = sales.groupby(by='ZIP CODE', as_index=False).median()[['ZIP CODE', 'price_perSqf']]
sales_median.head()
# Out:
#    ZIP CODE  price_perSqf
# 0   10001.0   1280.097512
# 1   10002.0   1039.603960
# 2   10003.0   1190.013196
# 3   10004.0   1250.746215
# 4   10005.0   1304.986441

# %%
# merge % complaints data with sales data

complaint_perc_bus = complaint_perc.loc[complaint_perc.loc_description == 'business', :]
comp_sales = complaint_perc_bus.merge(sales_median, left_on='Incident Zip', right_on='ZIP CODE')
comp_sales.head()
# Out:
#    Incident Zip loc_description  perc_complaints  ZIP CODE  price_perSqf
# 0       10001.0        business         8.798506   10001.0   1280.097512
# 1       10002.0        business         8.636890   10002.0   1039.603960
# 2       10003.0        business         8.313058   10003.0   1190.013196
# 3       10004.0        business        12.205567   10004.0   1250.746215
# 4       10005.0        business         5.210918   10005.0   1304.986441

# %%
# correlation

comp_sales[['perc_complaints', 'price_perSqf']].corr()
# Out:
#                  perc_complaints  price_perSqf
# perc_complaints         1.000000      0.518727
# price_perSqf            0.518727      1.000000

# %% [markdown]
# ~ 0.52 correlation

# %%
# plot as heatmap

comp_sales_plot = zips.merge(comp_sales, left_on='ZIPCODE', right_on='Incident Zip')
comp_sales_plot.plot(column='perc_complaints', figsize=(9,7), legend=True)
plt.title('% business complaints')
# Out:
# Text(0.5, 1.0, '% business complaints')

# %%
comp_sales_plot.plot(column='price_perSqf', scheme='quantiles', figsize=(9,7), legend=True)
plt.title('median price per sq.ft (USD)')
# Out:
# Text(0.5, 1.0, 'median price per sq.ft (USD)')

# %% [markdown]
# Both commercial complaints and high sale prices are concentrated in Manhattan, indicating centrality of the place could be a common cause for both...

# %% [markdown]
# ## noise complaints vs. neighborhood real estate
#
# Let's focus on 311 complaints regarding noise in particular and check if there's any relation between noise complaints amd the real estate market in an area.

# %%
# check the complaint types in the data

data['Complaint Type'].unique()
# Out:
# array(['Damaged Tree', 'Graffiti', 'Noise - Commercial', 'FATF',
#        'Overgrown Tree/Branches', 'Lost Property', 'Rodent',
#        'Illegal Parking', 'Broken Parking Meter',
#        'Non-Emergency Police Matter', 'Blocked Driveway',
#        'Noise - Residential', 'Street Condition', 'Sidewalk Condition',
#        'Noise - Helicopter', 'Street Sign - Damaged',
#        'Unsanitary Animal Pvt Property', 'For Hire Vehicle Complaint',
#        'Street Sign - Dangling', 'Noise - Vehicle',
#        'DEP Street Condition', 'Indoor Air Quality',
#        'Root/Sewer/Sidewalk Condition', 'Violation of Park Rules',
#        'Maintenance or Facility', 'Animal in a Park', 'Standing Water',
#        'Homeless Person Assistance', 'Noise - Park',
#        'DOF Property - Update Account', 'DOF Property - Request Copy',
#        'New Tree Request', 'Dead/Dying Tree',
#        'DOF Property - Reduction Issue', 'Abandoned Vehicle',
#        'Water System', 'SCRIE', 'Sewer', 'DOF Parking - Tax Exemption',
#        'DOF Property - Property Value', 'DOF Property - Owner Issue',
#        'DOF Property - Payment Issue', 'Elder Abuse',
#        'DOF Property - RPIE Issue', 'PLUMBING', 'Noise', 'Air Quality',
#        'Homeless Encampment', 'Traffic',
#        'Case Management Agency Complaint', 'DPR Internal',
#        'Noise - Street/Sidewalk', 'Radioactive Material',
#        'Beach/Pool/Sauna Complaint', 'Smoking', 'Vending',
#        'Unsanitary Condition', 'Unsanitary Pigeon Condition',
#        'Building/Use', 'School Maintenance',
#        'General Construction/Plumbing', 'Animal-Abuse',
#        'Food Establishment', 'For Hire Vehicle Report', 'Curb Condition',
#        'Illegal Tree Damage', 'Street Sign - Missing',
#        'Consumer Complaint', 'Taxi Report', 'Taxi Complaint',
#        'Mobile Food Vendor', 'Food Poisoning', 'Drug Activity',
#        'Street Light Condition',
#        'Special Projects Inspection Team (SPIT)',
#        'Bike/Roller/Skate Chronic', 'WATER LEAK', 'UNSANITARY CONDITION',
#        'Noise - House of Worship', 'Plumbing', 'Traffic Signal Condition',
#        'Bus Stop Shelter Complaint', 'Poison Ivy', 'Drinking',
#        'Illegal Fireworks', 'Tattooing', 'Indoor Sewage', 'Pet Shop',
#        'Highway Condition', 'Urinating in Public', 'ELEVATOR',
#        'Unleashed Dog', 'Taxi Compliment', 'Unsanitary Animal Facility',
#        'GENERAL', 'Mosquitoes', 'HEAT/HOT WATER', 'Drinking Water',
#        'Asbestos', 'Single Occupancy Bathroom', 'Mold', 'Panhandling',
#        'Green Taxi Complaint', 'Day Care', 'Fire Alarm - Replacement',
#        'Home Delivered Meal - Missed Delivery',
#        'Bus Stop Shelter Placement', 'DOOR/WINDOW', 'Illegal Animal Sold',
#        'Missed Collection', 'Harboring Bees/Wasps',
#        'Public Payphone Complaint', 'Home Delivered Meal Complaint',
#        'Illegal Animal Kept as Pet', 'FLOORING/STAIRS',
#        'Posting Advertisement', 'PAINT/PLASTER',
#        'Dispatched Taxi Compliment', 'Found Property',
#        'Bike Rack Condition', 'Squeegee', 'BEST/Site Safety', 'APPLIANCE',
#        'Municipal Parking Facility', 'Highway Sign - Damaged',
#        'Emergency Response Team (ERT)', 'Lifeguard', 'Industrial Waste',
#        'ELECTRIC', 'X-Ray Machine/Equipment', 'Disorderly Youth',
#        'Animal Facility - No Permit', 'Water Quality',
#        'Construction Lead Dust', 'Ferry Complaint', 'Public Toilet',
#        'Construction Safety Enforcement', 'Borough Office',
#        'Hazardous Materials', 'Bridge Condition', 'Ferry Inquiry',
#        'Water Conservation', 'Peeling Paint', 'Green Taxi Report',
#        'LinkNYC', 'Electrical', 'Elevator', 'General', 'Safety',
#        'Window Guard', 'Lead', 'Sustainability Enforcement', 'Boilers',
#        'SAFETY', 'Snow Removal', 'Derelict Bicycle', 'Bottled Water',
#        'Investigations and Discipline (IAD)', 'Vacant Lot',
#        'Highway Sign - Missing', 'Scaffold Safety',
#        'FHV Licensee Complaint', 'Calorie Labeling', 'Cooling Tower',
#        'Appliance', 'Dispatched Taxi Complaint', 'DEP Sidewalk Condition',
#        'Building Marshals office', 'Water Leak', 'Non-Residential Heat',
#        'Construction', 'Miscellaneous Categories', 'Ferry Permit',
#        'Highway Sign - Dangling', 'Tanning', 'Unlicensed Dog',
#        'Executive Inspections', 'Taxi Licensee Complaint',
#        'Missed Collection (All Materials)', 'Facades', 'Dirty Conditions',
#        'Sanitation Condition', 'SRDE',
#        'Request Large Bulky Item Collection', 'Sweeping/Missed',
#        'Housing - Low Income Senior', 'Litter Basket / Request',
#        'Overflowing Litter Baskets', 'Housing Options',
#        'Outside Building', 'Derelict Vehicles', 'Other Enforcement',
#        'Electric', 'Derelict Vehicle', 'Snow', 'Trans Fat',
#        'Quality of Life', 'Animal Abuse'], dtype=object)

# %%
# The complaint type corresponding to noise is "Noise - Commercial", 'Noise - Residential', 'Noise' etc.

# %%
# create another column indicating the complaint type as just two groups - "noise" and "other" for every other complaint

noise_complaints = ['Noise - Commercial', 'Noise - Residential', 'Noise - Street/Sidewalk', 
                   'Noise', 'Noise - Vehicle', 'Noise - House of Worship', 'Noise - Helicopter', 'Noise - Park']

data['complaint_description'] = 'other'
data.loc[data['Complaint Type'].isin(noise_complaints), 'complaint_description'] = 'noise'
data.head()
# Out:
#    Unique Key        Created Date Agency      Complaint Type  \
# 1    44079566 2019-10-17 08:25:14    DPR        Damaged Tree
# 2    45211021 2019-12-20 06:54:38   DSNY            Graffiti
# 3    45232110 2019-12-23 08:48:30   DSNY            Graffiti
# 4    43573777 2019-08-17 02:30:39   DSNY            Graffiti
# 5    43524214 2019-08-11 23:46:01   NYPD  Noise - Commercial
#
#       Location Type  Incident Zip   Latitude  Longitude  \
# 1   Street/Curbside       11434.0  40.670854 -73.771876
# 2         Mixed Use       11212.0  40.663072 -73.925752
# 3         Mixed Use       10016.0  40.744629 -73.976001
# 4       Residential       10032.0  40.835618 -73.945652
# 5  Store/Commercial       11420.0  40.675929 -73.818015
#
#                                   Location  complaint_hour complaint_time  \
# 1   (40.6708540271649, -73.77187597753328)               8       08:25:14
# 2  (40.66307167932628, -73.92575181328998)               6       06:54:38
# 3  (40.74462912186954, -73.97600102823421)               8       08:48:30
# 4   (40.83561762599567, -73.9456520072136)               2       02:30:39
# 5  (40.67592902161404, -73.81801548500097)              23       23:46:01
#
#    weekday complaint_description loc_description
# 1        3                 other           other
# 2        4                 other           other
# 3        0                 other           other
# 4        5                 other           other
# 5        6                 noise        business

# %%
# now calculate the noise complaints as a % of total 311 complaints for each zip

complaint_perc = data.groupby(by=['Incident Zip', 'complaint_description']).count()[['Unique Key']]
complaint_perc = complaint_perc.groupby(level=0).apply(lambda x:100 * x / float(x.sum()))
complaint_perc.reset_index(inplace=True)
complaint_perc.rename(columns={'Unique Key':'perc_complaints'}, inplace=True)
complaint_perc.head()
# Out:
#    Incident Zip complaint_description  perc_complaints
# 0       10001.0                 noise        21.083212
# 1       10001.0                 other        78.916788
# 2       10002.0                 noise        33.788132
# 3       10002.0                 other        66.211868
# 4       10003.0                 noise        26.371992

# %%
# merge the income data with 311 business noise % complaints

complaint_perc_bus = complaint_perc.loc[complaint_perc.complaint_description == 'noise', :]
comp_income = complaint_perc_bus.merge(income, left_on='Incident Zip', right_on='Zipcode')
comp_income.head()
# Out:
#    Incident Zip complaint_description  perc_complaints  Zipcode  \
# 0       10001.0                 noise        21.083212    10001
# 1       10002.0                 noise        33.788132    10002
# 2       10003.0                 noise        26.371992    10003
# 3       10004.0                 noise         8.137045    10004
# 4       10005.0                 noise        13.730356    10005
#
#    IncomePerCapita
# 0          77512.0
# 1          26905.0
# 2          79088.0
# 3          98020.0
# 4          99633.0

# %%
comp_income[['perc_complaints', 'IncomePerCapita']].corr()
# Out:
#                  perc_complaints  IncomePerCapita
# perc_complaints         1.000000        -0.325744
# IncomePerCapita        -0.325744         1.000000

# %%
# merge the income data with 311 business noise % complaints

complaint_perc_bus = complaint_perc.loc[complaint_perc.complaint_description == 'noise', :]
comp_sales = complaint_perc_bus.merge(sales_median, left_on='Incident Zip', right_on='ZIP CODE')
comp_sales.head()
# Out:
#    Incident Zip complaint_description  perc_complaints  ZIP CODE  price_perSqf
# 0       10001.0                 noise        21.083212   10001.0   1280.097512
# 1       10002.0                 noise        33.788132   10002.0   1039.603960
# 2       10003.0                 noise        26.371992   10003.0   1190.013196
# 3       10004.0                 noise         8.137045   10004.0   1250.746215
# 4       10005.0                 noise        13.730356   10005.0   1304.986441

# %%
comp_sales[['perc_complaints', 'price_perSqf']].corr()
# Out:
#                  perc_complaints  price_perSqf
# perc_complaints         1.000000     -0.248677
# price_perSqf           -0.248677      1.000000

# %%
comp_sales_plot = zips.merge(comp_sales, left_on='ZIPCODE', right_on='Incident Zip')
comp_income_plot = zips.merge(comp_income, left_on='ZIPCODE', right_on='Incident Zip')

plt.figure(figsize=(16, 9))
ax1 = plt.subplot(1, 2, 1)
comp_sales_plot.plot(column='perc_complaints', figsize=(9,7), legend=True, ax=ax1)
plt.title('% noise complaints')

ax2 = plt.subplot(1, 2, 2)
comp_income_plot.plot(column='IncomePerCapita', scheme='quantiles', k=6, figsize=(9,7), legend=True, ax=ax2)
plt.title('IncomePerCapita')
# Out:
# Text(0.5, 1.0, 'IncomePerCapita')

# %%
comp_sales_plot = zips.merge(comp_sales, left_on='ZIPCODE', right_on='Incident Zip')
comp_income_plot = zips.merge(comp_income, left_on='ZIPCODE', right_on='Incident Zip')

plt.figure(figsize=(16, 9))
ax1 = plt.subplot(1, 2, 1)
comp_sales_plot.plot(column='perc_complaints', figsize=(9,7), legend=True, ax=ax1)
plt.title('% noise complaints')

ax2 = plt.subplot(1, 2, 2)
comp_sales_plot.plot(column='price_perSqf', scheme='quantiles', k=6, figsize=(9,7), legend=True, ax=ax2)
plt.title('price per sq ft')
# Out:
# Text(0.5, 1.0, 'price per sq ft')
